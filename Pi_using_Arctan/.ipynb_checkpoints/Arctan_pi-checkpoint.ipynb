# %% [markdown]
# # Calculating $\pi$ using Machin-like formula
# This equation was discovered in 1706 by John Machin, and has been in use for around 300 years. It is suitable for the calculation of Pi because it converges quickly.
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
#
# Sources:
# https://en.wikipedia.org/wiki/Machin-like_formula
# https://www.youtube.com/watch?v=enQdwZwoyyo

# %%
from decimal import getcontext
from decimal import Decimal as dec
from math import atan, pi
import time

# %%
ctx = getcontext()
digits = 2000
ctx.prec = digits
terms_5 = 2000
terms_239 = 500

# %%
def arctan(x,n):
    x = dec(x)
    total = dec(0)
    # for -1 <= x <= 1
    for i in range(n):
        sign = -1 if i%2 else 1
        f = dec(2*i + 1)
        denom = dec(f * dec(x**f))
        total += dec(sign / denom)
    return total

# %%
def pie(fun):
    if fun==1:
        at1 = dec(atan(dec(1/5)))
        at2 = dec(atan(dec(1/239)))
    elif fun==2:
        # Machin-like formula
        at1 = arctan(5, terms_5)
        at2 = arctan(239, terms_239)
    elif fun==3:
        # arctan properties
        return dec(4*(arctan(2,terms_5)+arctan(3,terms_239)))
    
    return dec(4 * dec(4*at1 - at2))

# %%
# accurate upto 50k decimal places
a='3....'

# %%
pi1 = pie(2)
pi2 = pie(3)
print('Using math atan          : ', pie(1))
print('Using Machin formula     : ',pi1)
print('Using arctan properties  : ',pi2)
# Out:
# Using math atan          :  3.141592653589793508045469039302588498685508966445922851562500
# Using Machin formula     :  3....
# Using arctan properties  :  3....

# %%
print('Accurate pi     : ',a[:digits])
# Out:
# Accurate pi     :  3....

# %%
p = a[:digits]
pi2 = str(pi2)
pi1 = str(pi1)
count=0
i=0
while(i<digits):
    if pi1[i]!=p[i]:
        break
    count+=1
    i+=1
print("Accurate of pi1 upto: ", count)

count=0
i=0
while(i<digits):
    if pi2[i]!=p[i]:
        break
    count+=1
    i+=1
print("Accurate of pi2 upto: ", count)
# Out:
# Accurate of pi1 upto:  1999
# Accurate of pi2 upto:  481

# %%
## Time taken

a= time.time()
pi=pie(2)
print("Time for calculating {} arctan terms: {}s".format(terms_5, time.time()-a))
# Out:
# Time for calculating 2000 arctan terms: 0.4735383987426758s
